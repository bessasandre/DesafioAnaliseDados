# %% [markdown]
# <a href="https://colab.research.google.com/github/bessasandre/DesafioAnaliseDados/blob/main/Desafio_AnaliseDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# − rec_id: índice do registro de locação;
#
# − datetime: data;
#
# − season: estação do ano (1: inverno, 2: primavera, 3: verão, 4: outono). Relativo ao hemisfério norte;
#
# − year: ano (0: 2011, 1:2012);
#
# − month: mês (1 a 12);
#
# − hour: hora do dia (0 a 23);
#
# − is_holiday: booleano indicando feriado;
#
# − weekday: dia da semana (0: domingo, 1: segunda-feira, …, 6: sábado);
#
# − is_workingday: booleano indicando dia útil;
#
# − weather_condition: (1: limpo, 2: nublado, 3: chuva leve, 4: chuva forte);
#
# − temp: Temperatura escalada entre 0 e 1. Valor original em graus Celsius: -8 a 39;
#
# − atemp: Sensação térmica escalada entre 0 e 1. Valor original em graus Celsius: -16 a 50;
#
# − humidity: Humidade relativa (0 a 1);
#
# − windspeed: Velocidade do vento escalada entre 0 e 1 (máximo original: 67);
#
# − casual: número de locações para usuários casuais;
#
# − registered: número de locações para usuários registrados;
#
# − total_count: contador total de aluguéis (casual+registered).

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("https://pycourse.s3.amazonaws.com/bike-sharing.csv")

# %%
df
# Out:
#          datetime  rec_id  season  ...  casual  registered  total_count
# 0      2011-01-01       1       1  ...       3          13           16
# 1      2011-01-01       2       1  ...       8          32           40
# 2      2011-01-01       3       1  ...       5          27           32
# 3      2011-01-01       4       1  ...       3          10           13
# 4      2011-01-01       5       1  ...       0           1            1
# ...           ...     ...     ...  ...     ...         ...          ...
# 17374  2012-12-31   17375       1  ...      11         108          119
# 17375  2012-12-31   17376       1  ...       8          81           89
# 17376  2012-12-31   17377       1  ...       7          83           90
# 17377  2012-12-31   17378       1  ...      13          48           61
# 17378  2012-12-31   17379       1  ...      12          37           49
#
# [17379 rows x 17 columns]

# %% [markdown]
# Qual a média da coluna windspeed?

# %%
df['windspeed']
# Out:
# 0        0.0000
# 1        0.0000
# 2        0.0000
# 3        0.0000
# 4        0.0000
#           ...
# 17374    0.1642
# 17375    0.1642
# 17376    0.1642
# 17377    0.1343
# 17378    0.1343
# Name: windspeed, Length: 17379, dtype: float64

# %%
df['windspeed'].mean()
# Out:
# 0.1900976063064631

# %% [markdown]
# Qual a média da coluna temp?

# %%
df['temp']
# Out:
# 0        0.24
# 1        0.22
# 2        0.22
# 3        0.24
# 4        0.24
#          ...
# 17374    0.26
# 17375    0.26
# 17376    0.26
# 17377    0.26
# 17378    0.26
# Name: temp, Length: 17379, dtype: float64

# %%
df['temp'].mean()
# Out:
# 0.4969871684216586

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df.head()
# Out:
#     datetime  rec_id  season  year  ...  windspeed  casual  registered  total_count
# 0 2011-01-01       1       1     0  ...        0.0       3          13           16
# 1 2011-01-01       2       1     0  ...        0.0       8          32           40
# 2 2011-01-01       3       1     0  ...        0.0       5          27           32
# 3 2011-01-01       4       1     0  ...        0.0       3          10           13
# 4 2011-01-01       5       1     0  ...        0.0       0           1            1
#
# [5 rows x 17 columns]

# %%
df= df.set_index('datetime')

# %%
df.head()
# Out:
#             rec_id  season  year  ...  casual  registered  total_count
# datetime                          ...
# 2011-01-01       1       1     0  ...       3          13           16
# 2011-01-01       2       1     0  ...       8          32           40
# 2011-01-01       3       1     0  ...       5          27           32
# 2011-01-01       4       1     0  ...       3          10           13
# 2011-01-01       5       1     0  ...       0           1            1
#
# [5 rows x 16 columns]

# %%
df.dtypes
# Out:
# rec_id                 int64
# season                 int64
# year                   int64
# month                  int64
# hour                   int64
# is_holiday             int64
# weekday                int64
# is_workingday          int64
# weather_condition      int64
# temp                 float64
# atemp                float64
# humidity             float64
# windspeed            float64
# casual                 int64
# registered             int64
# total_count            int64
# dtype: object

# %% [markdown]
# Quantas locações de bicicletas foram efetuadas em 2011?
#
#
# ---

# %%
df[df.index<= '2011-12-31']
# Out:
#             rec_id  season  year  ...  casual  registered  total_count
# datetime                          ...
# 2011-01-01       1       1     0  ...       3          13           16
# 2011-01-01       2       1     0  ...       8          32           40
# 2011-01-01       3       1     0  ...       5          27           32
# 2011-01-01       4       1     0  ...       3          10           13
# 2011-01-01       5       1     0  ...       0           1            1
# ...            ...     ...   ...  ...     ...         ...          ...
# 2011-12-31    8641       1     0  ...      19          73           92
# 2011-12-31    8642       1     0  ...       8          63           71
# 2011-12-31    8643       1     0  ...       2          50           52
# 2011-12-31    8644       1     0  ...       2          36           38
# 2011-12-31    8645       1     0  ...       4          27           31
#
# [8645 rows x 16 columns]

# %%
df2 = df[df.index<= '2011-12-31'].copy()

# %%
df2
# Out:
#             rec_id  season  year  ...  casual  registered  total_count
# datetime                          ...
# 2011-01-01       1       1     0  ...       3          13           16
# 2011-01-01       2       1     0  ...       8          32           40
# 2011-01-01       3       1     0  ...       5          27           32
# 2011-01-01       4       1     0  ...       3          10           13
# 2011-01-01       5       1     0  ...       0           1            1
# ...            ...     ...   ...  ...     ...         ...          ...
# 2011-12-31    8641       1     0  ...      19          73           92
# 2011-12-31    8642       1     0  ...       8          63           71
# 2011-12-31    8643       1     0  ...       2          50           52
# 2011-12-31    8644       1     0  ...       2          36           38
# 2011-12-31    8645       1     0  ...       4          27           31
#
# [8645 rows x 16 columns]

# %%
df2['total_count']
# Out:
# datetime
# 2011-01-01    16
# 2011-01-01    40
# 2011-01-01    32
# 2011-01-01    13
# 2011-01-01     1
#               ..
# 2011-12-31    92
# 2011-12-31    71
# 2011-12-31    52
# 2011-12-31    38
# 2011-12-31    31
# Name: total_count, Length: 8645, dtype: int64

# %%
df2['total_count'].sum()
# Out:
# 1243103

# %% [markdown]
# Quantas locações de bicicletas foram efetuadas em 2012?

# %%
df[df.index>= '2012-01-01']
# Out:
#             rec_id  season  year  ...  casual  registered  total_count
# datetime                          ...
# 2012-01-01    8646       1     1  ...       5          43           48
# 2012-01-01    8647       1     1  ...      15          78           93
# 2012-01-01    8648       1     1  ...      16          59           75
# 2012-01-01    8649       1     1  ...      11          41           52
# 2012-01-01    8650       1     1  ...       0           8            8
# ...            ...     ...   ...  ...     ...         ...          ...
# 2012-12-31   17375       1     1  ...      11         108          119
# 2012-12-31   17376       1     1  ...       8          81           89
# 2012-12-31   17377       1     1  ...       7          83           90
# 2012-12-31   17378       1     1  ...      13          48           61
# 2012-12-31   17379       1     1  ...      12          37           49
#
# [8734 rows x 16 columns]

# %%
df3 = df[df.index>= '2012-01-01'].copy()

# %%
df3
# Out:
#             rec_id  season  year  ...  casual  registered  total_count
# datetime                          ...
# 2012-01-01    8646       1     1  ...       5          43           48
# 2012-01-01    8647       1     1  ...      15          78           93
# 2012-01-01    8648       1     1  ...      16          59           75
# 2012-01-01    8649       1     1  ...      11          41           52
# 2012-01-01    8650       1     1  ...       0           8            8
# ...            ...     ...   ...  ...     ...         ...          ...
# 2012-12-31   17375       1     1  ...      11         108          119
# 2012-12-31   17376       1     1  ...       8          81           89
# 2012-12-31   17377       1     1  ...       7          83           90
# 2012-12-31   17378       1     1  ...      13          48           61
# 2012-12-31   17379       1     1  ...      12          37           49
#
# [8734 rows x 16 columns]

# %%
df3['total_count'].sum()
# Out:
# 2049576

# %%
df["total_count"]
# Out:
# datetime
# 2011-01-01     16
# 2011-01-01     40
# 2011-01-01     32
# 2011-01-01     13
# 2011-01-01      1
#              ...
# 2012-12-31    119
# 2012-12-31     89
# 2012-12-31     90
# 2012-12-31     61
# 2012-12-31     49
# Name: total_count, Length: 17379, dtype: int64

# %%
df["total_count"].sum()
# Out:
# 3292679

# %% [markdown]
# Qual horário do dia contém a maior média de locações de bicicletas?
#
# Qual horário do dia contém a menor média de locações de bicicletas?

# %%
df.sort_values(by=['hour','total_count'])
# Out:
#             rec_id  season  year  ...  casual  registered  total_count
# datetime                          ...
# 2011-02-02     712       1     0  ...       0           2            2
# 2011-01-19     409       1     0  ...       0           3            3
# 2011-03-10    1552       1     0  ...       3           0            3
# 2011-03-31    2044       2     0  ...       0           3            3
# 2012-01-12    8908       1     1  ...       0           3            3
# ...            ...     ...   ...  ...     ...         ...          ...
# 2012-06-02   12331       2     1  ...      53         185          238
# 2012-05-19   11995       2     1  ...      71         168          239
# 2012-07-25   13603       3     1  ...      52         187          239
# 2012-09-07   14659       3     1  ...      28         220          248
# 2012-05-04   11635       2     1  ...      51         205          256
#
# [17379 rows x 16 columns]

# %%
df6= df.groupby(by='hour').mean()

# %%
df6
# Out:
#            rec_id    season      year  ...     casual  registered  total_count
# hour                                   ...
# 0     8677.683196  2.500000  0.502755  ...  10.158402   43.739669    53.898072
# 1     8672.640884  2.497238  0.502762  ...   6.504144   26.871547    33.375691
# 2     8746.538462  2.511888  0.507692  ...   4.772028   18.097902    22.869930
# 3     8819.661406  2.539455  0.509326  ...   2.715925    9.011478    11.727403
# 4     8892.555237  2.552367  0.516499  ...   1.253945    5.098996     6.352941
# 5     8758.301255  2.513250  0.507671  ...   1.411437   18.478382    19.889819
# 6     8674.376552  2.497931  0.502069  ...   4.161379   71.882759    76.044138
# 7     8660.155433  2.496561  0.500688  ...  11.055021  201.009629   212.064649
# 8     8661.155433  2.496561  0.500688  ...  21.679505  337.331499   359.011004
# 9     8662.155433  2.496561  0.500688  ...  30.891334  188.418157   219.309491
# ...

# %%
df6.sort_values('total_count')
# Out:
#            rec_id    season      year  ...     casual  registered  total_count
# hour                                   ...
# 4     8892.555237  2.552367  0.516499  ...   1.253945    5.098996     6.352941
# 3     8819.661406  2.539455  0.509326  ...   2.715925    9.011478    11.727403
# 5     8758.301255  2.513250  0.507671  ...   1.411437   18.478382    19.889819
# 2     8746.538462  2.511888  0.507692  ...   4.772028   18.097902    22.869930
# 1     8672.640884  2.497238  0.502762  ...   6.504144   26.871547    33.375691
# 0     8677.683196  2.500000  0.502755  ...  10.158402   43.739669    53.898072
# 6     8674.376552  2.497931  0.502069  ...   4.161379   71.882759    76.044138
# 23    8678.884615  2.495879  0.501374  ...  15.199176   72.631868    87.831044
# 22    8677.884615  2.495879  0.501374  ...  22.252747  109.082418   131.335165
# 21    8676.884615  2.495879  0.501374  ...  28.255495  144.059066   172.314560
# ...

# %% [markdown]
# Que dia da semana contém a maior média de locações de bicicletas?
#
# Que dia da semana contém a menor média de locações de bicicletas?

# %%
df7= df.groupby(by='weekday').mean()

# %%
df7
# Out:
#               rec_id    season      year  ...     casual  registered  total_count
# weekday                                   ...
# 0        8697.580735  2.490408  0.507994  ...  56.163469  121.305356   177.468825
# 1        8645.734167  2.488503  0.501815  ...  28.553449  155.191206   183.744655
# 2        8665.830004  2.529148  0.501834  ...  23.580514  167.658377   191.238891
# 3        8703.582222  2.510707  0.503434  ...  23.159192  167.971313   191.130505
# 4        8739.579927  2.521651  0.504249  ...  24.872521  171.564144   196.436665
# 5        8725.739043  2.495778  0.501809  ...  31.458786  164.677121   196.135907
# 6        8652.199841  2.476115  0.496815  ...  61.246815  128.962978   190.209793
#
# [7 rows x 15 columns]

# %%
df7.sort_values('total_count')
# Out:
#               rec_id    season      year  ...     casual  registered  total_count
# weekday                                   ...
# 0        8697.580735  2.490408  0.507994  ...  56.163469  121.305356   177.468825
# 1        8645.734167  2.488503  0.501815  ...  28.553449  155.191206   183.744655
# 6        8652.199841  2.476115  0.496815  ...  61.246815  128.962978   190.209793
# 3        8703.582222  2.510707  0.503434  ...  23.159192  167.971313   191.130505
# 2        8665.830004  2.529148  0.501834  ...  23.580514  167.658377   191.238891
# 5        8725.739043  2.495778  0.501809  ...  31.458786  164.677121   196.135907
# 4        8739.579927  2.521651  0.504249  ...  24.872521  171.564144   196.436665
#
# [7 rows x 15 columns]

# %% [markdown]
# Às quartas-feiras (weekday = 3), qual o horário do dia contém a maior média
# de locações de bicicletas?

# %%
df10 = df[df['weekday']== 3]

# %%
df11= df10.groupby(by='hour').mean()

# %%
df11

# %%
df11.sort_values('total_count')
# Out:
#            rec_id    season      year  ...     casual  registered  total_count
# hour                                   ...
# 3     8994.979798  2.545455  0.525253  ...   0.656566    4.232323     4.888889
# 4     9003.781250  2.604167  0.520833  ...   0.552083    4.416667     4.968750
# 2     8783.205882  2.529412  0.509804  ...   1.519608    6.294118     7.813725
# 1     8639.586538  2.500000  0.500000  ...   2.788462   12.548077    15.336538
# 5     8643.442308  2.500000  0.500000  ...   1.259615   24.490385    25.750000
# 0     8638.586538  2.500000  0.500000  ...   5.875000   28.682692    34.557692
# 23    8739.776699  2.514563  0.504854  ...  12.184466   71.553398    83.737864
# 6     8644.442308  2.500000  0.500000  ...   4.480769  103.326923   107.807692
# 10    8648.442308  2.500000  0.500000  ...  27.009615  104.884615   131.894231
# 22    8738.776699  2.514563  0.504854  ...  19.310680  124.378641   143.689320
# ...

# %% [markdown]
# Aos sábados (weekday = 6), qual o horário do dia contém a maior média de
# locações de bicicletas?

# %%
df12 = df[df['weekday']== 6]

# %%
df13= df12.groupby(by='hour').mean()

# %%
df13.sort_values('total_count')
# Out:
#            rec_id    season      year  ...      casual  registered  total_count
# hour                                   ...
# 4     8631.114286  2.476190  0.495238  ...    2.095238    5.561905     7.657143
# 5     8788.961165  2.504854  0.504854  ...    1.592233    6.699029     8.291262
# 6     8633.095238  2.476190  0.495238  ...    4.209524   16.790476    21.000000
# 3     8630.114286  2.476190  0.495238  ...    5.104762   17.780952    22.885714
# 7     8634.095238  2.476190  0.495238  ...    8.247619   37.714286    45.961905
# 2     8629.114286  2.476190  0.495238  ...    8.780952   41.714286    50.495238
# 1     8628.114286  2.476190  0.495238  ...   10.714286   57.066667    67.780952
# 0     8627.114286  2.476190  0.495238  ...   15.514286   78.790476    94.304762
# 8     8635.095238  2.476190  0.495238  ...   19.809524   94.666667   114.476190
# 23    8679.019231  2.471154  0.500000  ...   25.778846   90.076923   115.855769
# ...

# %%
df16= df.groupby(by='weather_condition').mean()

# %%
df16
# Out:
#                         rec_id    season  ...  registered  total_count
# weather_condition                         ...
# 1                  8696.750723  2.511084  ...  164.323841   204.869272
# 2                  8828.604533  2.492518  ...  145.570202   175.165493
# 3                  8197.145877  2.458069  ...   95.523608   111.579281
# 4                  6188.333333  1.000000  ...   71.666667    74.333333
#
# [4 rows x 15 columns]
